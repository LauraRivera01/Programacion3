# %% [markdown]
# <a href="https://colab.research.google.com/github/LauraRivera01/Programacion3/blob/main/ActividadC2Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-f0c24429-e475-4de1-839a-b7d034cf95cd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f0c24429-e475-4de1-839a-b7d034cf95cd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving trx_tarjetas_credito.csv to trx_tarjetas_credito.csv
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pf
print(archivo)
# Out:
#                         City       Date  Card Type Exp Type Gender  Amount
# 0               Delhi, India  29-Oct-14       Gold    Bills      F   82475
# 1      Greater Mumbai, India  22-Aug-14   Platinum    Bills      F   32555
# 2           Bengaluru, India  27-Aug-14     Silver    Bills      F  101738
# 3      Greater Mumbai, India  12-Apr-14  Signature    Bills      F  123424
# 4           Bengaluru, India   5-May-15       Gold    Bills      F  171574
# ...                      ...        ...        ...      ...    ...     ...
# 26047         Kolkata, India  22-Jun-14     Silver   Travel      F  128191
# 26048            Pune, India   3-Aug-14  Signature   Travel      M  246316
# 26049       Hyderabad, India  16-Jan-15     Silver   Travel      M  265019
# 26050          Kanpur, India  14-Sep-14     Silver   Travel      M   88174
# 26051       Hyderabad, India  19-Oct-13  Signature    Bills      M  184410
#
# [26052 rows x 6 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

archivo = pd.read_csv("trx_tarjetas_credito.csv")

x=archivo["Gender"]
y=archivo["Amount"]
plt.bar(x,y)
plt.xlabel("Genero")
plt.ylabel("Suma")
plt.show()
wb.save('Prueba14.xlsx')

# %%
import pandas as pd
import matplotlib.pyplot as plt

archivo = pd.read_csv("trx_tarjetas_credito.csv")

x=archivo["Card Type"]
y=archivo["Amount"]
plt.bar(x,y)
plt.xlabel("Tarjeta")
plt.ylabel("Suma")
plt.show()
wb.save('Prueba13.xlsx')

# %%
import pandas as pd
import matplotlib.pyplot as plt

archivo = pd.read_csv("trx_tarjetas_credito.csv")

x=archivo["Date"]
y=archivo["Amount"]
plt.bar(x,y)
plt.xlabel("Fecha")
plt.ylabel("Suma")
plt.show()
wb.save('Prueba12.xlsx')

# %%
import openpyxl
wb = openpyxl.Workbook()

# %%
wb.save('Prueba12.xlsx')

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
